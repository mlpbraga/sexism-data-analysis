# %%
import pandas as pd
import numpy as np
from modules.database_connector import Database

database = Database()
conn = database.get_connection()
# Out:
# Cannot connect to Postgres [ec2-54-84-35-171.compute-1.amazonaws.com]
# connection to server at "ec2-54-84-35-171.compute-1.amazonaws.com" (54.84.35.171), port 5432 failed: could not receive data from server: Operation timed out

# %%
from modules.read_dataframe import Comments

# %%
comments = Comments(conn, remake=False)
# Out:
# /opt/homebrew/lib/python3.9/site-packages/sklearn/utils/deprecation.py:87: FutureWarning: Function get_feature_names is deprecated; get_feature_names is deprecated in 1.0 and will be removed in 1.2. Please use get_feature_names_out instead.
#   warnings.warn(msg, category=FutureWarning)
# ...

# %% [markdown]
# ---

# %%
comments.sexist_words.head(15)
# Out:
#             word  sexist-freq  not-sexist-freq  undefined-freq      diff
# 3810    mulheres     0.010089         0.006117           0.004  0.003972
# 3799      homens     0.006657         0.004023           0.004  0.002635
# 3801         ela     0.007449         0.005120           0.010  0.002329
# 3812         uma     0.012113         0.009841           0.026  0.002272
# 3809      mulher     0.010030         0.007780           0.018  0.002251
# 3817          de     0.040942         0.038731           0.036  0.002211
# 3760        feia     0.002141         0.000199           0.002  0.001941
# 3806          as     0.008916         0.006982           0.006  0.001934
# 3770        elas     0.002434         0.000532           0.002  0.001902
# 3765     assédio     0.002317         0.000831           0.000  0.001486
# 3747         diz     0.001701         0.000299           0.002  0.001402
# 3753  feministas     0.001848         0.000499           0.000  0.001349
# 3769   feminismo     0.002405         0.001064           0.000  0.001341
# 3813         com     0.012230         0.010905           0.024  0.001325
# 3802          na     0.007801         0.006483           0.004  0.001318

# %%
comments.not_sexist_words.head(15)
# Out:
#              word  sexist-freq  not-sexist-freq  undefined-freq      diff
# 3795          ser     0.005367         0.008178           0.004 -0.002811
# 3676       Brasil     0.000997         0.002726           0.004 -0.001729
# 3715          sua     0.001408         0.003025           0.004 -0.001618
# 3804           em     0.008417         0.009940           0.004 -0.001523
# 3724         você     0.001496         0.002859           0.004 -0.001363
# 3501        sobre     0.000499         0.001729           0.000 -0.001230
# 3694      pessoas     0.001114         0.002327           0.000 -0.001213
# 3343  comentários     0.000352         0.001563           0.000 -0.001211
# 3779         como     0.003109         0.004189           0.004 -0.001080
# 3816          não     0.022113         0.023172           0.032 -0.001059
# 3593          lei     0.000704         0.001729           0.004 -0.001025
# 3767         está     0.002376         0.003391           0.004 -0.001015
# 3276   presidente     0.000293         0.001297           0.000 -0.001003
# 3797           os     0.006012         0.006982           0.008 -0.000969
# 3811           do     0.011555         0.012401           0.018 -0.000845

# %%
comments.sexist_bigrams.head(15)
# Out:
#                word  sexist-freq  not-sexist-freq  undefined-freq      diff
# 4165    as mulheres     0.009779         0.005238        0.007874  0.004540
# 4155        diz que     0.003703         0.000428        0.000000  0.003275
# 4153     que homens     0.003418         0.000535        0.000000  0.002883
# 4154        que vai     0.003418         0.000748        0.000000  0.002669
# 4158         que as     0.004462         0.002138        0.000000  0.002324
# 4150      mesmo que     0.003228         0.001176        0.000000  0.002052
# 4163     uma mulher     0.006076         0.004062        0.023622  0.002014
# 4146       um homem     0.002753         0.000855        0.007874  0.001898
# 4145   mulheres não     0.002658         0.000962        0.000000  0.001696
# 4161      os homens     0.004747         0.003207        0.007874  0.001540
# 4127  as feministas     0.001899         0.000535        0.000000  0.001364
# 4157         do que     0.004462         0.003100        0.000000  0.001362
# 4111    são minoria     0.001519         0.000214        0.000000  0.001305
# 4140   das mulheres     0.002279         0.001069        0.000000  0.001209
# 4130      por causa     0.001899         0.000748        0.000000  0.001150

# %%
comments.not_sexist_bigrams.head(15)
# Out:
#              word  sexist-freq  not-sexist-freq  undefined-freq      diff
# 4164      que não     0.007690         0.010263        0.007874 -0.002573
# 3965   ser humano     0.000665         0.002352        0.000000 -0.001687
# 4118    no Brasil     0.001709         0.003314        0.007874 -0.001605
# 4152      tem que     0.003323         0.004918        0.000000 -0.001595
# 4041     que você     0.000854         0.002245        0.007874 -0.001391
# 3883       ou não     0.000570         0.001924        0.007874 -0.001355
# 4086      que ser     0.001139         0.002459        0.000000 -0.001320
# 4122     todos os     0.001709         0.002993        0.000000 -0.001284
# 4068   as pessoas     0.001044         0.002245        0.000000 -0.001201
# 3365  pessoas que     0.000285         0.001390        0.000000 -0.001105
# 2356      Tem que     0.000190         0.001283        0.000000 -0.001093
# 4144      tipo de     0.002468         0.003528        0.000000 -0.001059
# 3999     não sabe     0.000760         0.001817        0.000000 -0.001058
# 3825   todo mundo     0.000475         0.001497        0.000000 -0.001022
# 3664     sabe que     0.000380         0.001390        0.000000 -0.001010

# %%
comments.print_frequecies_to_latex('nsb', 15)
# Out:
# {que não} & {0.007690} & {0.010263} & {-0.002573}\\
# {ser humano} & {0.000665} & {0.002352} & {-0.001687}\\
# {no Brasil} & {0.001709} & {0.003314} & {-0.001605}\\
# {tem que} & {0.003323} & {0.004918} & {-0.001595}\\
# {que você} & {0.000854} & {0.002245} & {-0.001391}\\
# {ou não} & {0.000570} & {0.001924} & {-0.001355}\\
# {que ser} & {0.001139} & {0.002459} & {-0.001320}\\
# {todos os} & {0.001709} & {0.002993} & {-0.001284}\\
# {as pessoas} & {0.001044} & {0.002245} & {-0.001201}\\
# {pessoas que} & {0.000285} & {0.001390} & {-0.001105}\\
# {Tem que} & {0.000190} & {0.001283} & {-0.001093}\\
# {tipo de} & {0.002468} & {0.003528} & {-0.001059}\\
# {não sabe} & {0.000760} & {0.001817} & {-0.001058}\\
# {todo mundo} & {0.000475} & {0.001497} & {-0.001022}\\
# {sabe que} & {0.000380} & {0.001390} & {-0.001010}\\

# %% [markdown]
# ---
